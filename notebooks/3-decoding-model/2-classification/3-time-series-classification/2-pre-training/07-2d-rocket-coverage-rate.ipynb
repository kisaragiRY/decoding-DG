# %% [markdown]
# # Calculate the coverage rate for 2d rocker kernel

# %%
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from param import *
from dataloader.dataset import UniformSegmentDataset

sns.set_theme(style="whitegrid")
output_dir = ParamDir().output_dir
datalist = ParamDir().data_path_list

# %% [markdown]
# ## Plot for the internal and external states

# %%
for data_dir in datalist:
    data_name = str(data_dir).split('/')[-1]
    K, num_kernels = 16, 35

    # ---- data prep ----
    dataset = UniformSegmentDataset(data_dir, ParamData().mobility, ParamData().shuffle, ParamData().random_state)
    (X_train, y_train) = dataset.load_all_data(ParamData().window_size, K)

    with open(ParamDir().output_dir/data_name/(f"tsc_2d_rocket_tuning_k_means_small_scale.pickle"),"rb") as f:
        result_all = pickle.load(f)
    result = [result for result in result_all if ((result["K"]==K) and (result["num_kernels"]==num_kernels))][0]

    # ---- plot ----
    labels = result['estimator'].labels_
    fig, axes = plt.subplots(nrows=2, ncols=2, tight_layout=True, sharex=True, sharey=True)
    axes = axes.ravel()
    for i, label in enumerate(np.unique(labels)):
        y_train = np.array([int(float(i)) for i in y_train])
        y, y_counts = np.unique(y_train[np.where(labels==label)], return_counts=True)
        axes[i].bar(y, y_counts)
        axes[i].set_title(f"label: {label}")
        axes[i].set_ylabel("count")
        axes[i].set_xlabel("position")

    mouse_type = "KO" if "KO" in data_name else "WT"
    plt.suptitle(mouse_type)
    plt.savefig(ParamDir().output_dir/data_name/(f"plot_2d_rocket_coverage.png"))
    plt.close(fig)

# %% [markdown]
# ## Coverage Rate

# %% [markdown]
# ### K-means

# %%
cr_list = []
K, num_kernels = 16, 35
for data_dir in datalist:
    # ---- data prep ----
    data_name = str(data_dir).split('/')[-1]
    dataset = UniformSegmentDataset(data_dir, ParamData().mobility, ParamData().shuffle, ParamData().random_state)
    (X_train, y_train) = dataset.load_all_data(ParamData().window_size, K)

    with open(ParamDir().output_dir/data_name/(f"tsc_2d_rocket_tuning_k_means_small_scale.pickle"),"rb") as f:
        result_all = pickle.load(f)
    result = [result for result in result_all if ((result["K"]==K) and (result["num_kernels"]==num_kernels))][0]

    # ---- prediction ----
    labels = result['estimator'].labels_
    adjusted_labels = np.zeros(len(labels))
    y_train = np.array([int(float(i)) for i in y_train])
    for label in np.unique(labels):
        y, y_counts = np.unique(y_train[np.where(labels==label)], return_counts=True)
        predicted_y = y[np.argmax(y_counts)]
        adjusted_labels[np.where(labels==label)] = predicted_y
    coverage_rate = np.sum(adjusted_labels==y_train)/len(y_train)
    if "KO" in data_name:
        cr_list.append([coverage_rate, "KO"])
    else:
        cr_list.append([coverage_rate, "WT"])

# ---- plot ----
df_plot = pd.DataFrame(cr_list, columns=["coverage rate", "mouse type"])
fig, ax = plt.subplots()
sns.boxplot(x="mouse type", y="coverage rate", data=df_plot, ax=ax)
plt.suptitle("coverage rate(K-means)")
# Out:
# Text(0.5, 0.98, 'coverage rate(K-means)')

# %% [markdown]
# ### Spectral Clustering

# %%
cr_list = []
for data_dir in datalist:
    # ---- data prep ----
    data_name = str(data_dir).split('/')[-1]
    dataset = UniformSegmentDataset(data_dir, ParamData().mobility, ParamData().shuffle, ParamData().random_state)
    (X_train, y_train) = dataset.load_all_data(ParamData().window_size, K)

    with open(ParamDir().output_dir/data_name/(f"tsc_tuning_spectral_small_scale.pickle"),"rb") as f:
        result_all = pickle.load(f)
    result = [result for result in result_all if ((result["K"]==K) and (result["num_kernels"]==num_kernels))][0]

    # ---- prediction ----
    labels = result['estimator'].labels_
    adjusted_labels = np.zeros(len(labels))
    y_train = np.array([int(float(i)) for i in y_train])
    for label in np.unique(labels):
        y, y_counts = np.unique(y_train[np.where(labels==label)], return_counts=True)
        predicted_y = y[np.argmax(y_counts)]
        adjusted_labels[np.where(labels==label)] = predicted_y
    coverage_rate = np.sum(adjusted_labels==y_train)/len(y_train)
    if "KO" in data_name:
        cr_list.append([coverage_rate, "KO"])
    else:
        cr_list.append([coverage_rate, "WT"])

# ---- plot ----
df_plot = pd.DataFrame(cr_list, columns=["coverage rate", "mouse type"])
fig, ax = plt.subplots()
sns.boxplot(x="mouse type", y="coverage rate", data=df_plot, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /work/notebooks/3-decoding-model/2-classification/3-time-series-classification/2-pre-training/07-2d-rocket-coverage-rate.ipynb Cell 9 in 1
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64672d656e636f6465722d6465636f646572222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6467783031227d7d/work/notebooks/3-decoding-model/2-classification/3-time-series-classification/2-pre-training/07-2d-rocket-coverage-rate.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> with open(ParamDir().output_dir/data_name/(f"tsc_tuning_spectral_small_scale.pickle"),"rb") as f:
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64672d656e636f6465722d6465636f646572222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6467783031227d7d/work/notebooks/3-decoding-model/2-classification/3-time-series-classification/2-pre-training/07-2d-rocket-coverage-rate.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     result_all = pickle.load(f)
# ---> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64672d656e636f6465722d6465636f646572222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6467783031227d7d/work/notebooks/3-decoding-model/2-classification/3-time-series-classification/2-pre-training/07-2d-rocket-coverage-rate.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> result = [result for result in result_all if ((result["K"]==K) and (result["num_kernels"]==num_kernels))][0]
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64672d656e636f6465722d6465636f646572222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6467783031227d7d/work/notebooks/3-decoding-model/2-classification/3-time-series-classification/2-pre-training/07-2d-rocket-coverage-rate.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> # ---- prediction ----
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64672d656e636f6465722d6465636f646572222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6467783031227d7d/work/notebooks/3-decoding-model/2-classification/3-time-series-classification/2-pre-training/07-2d-rocket-coverage-rate.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> labels = result['estimator'].labels_
#
# IndexError: list index out of range

# %%
[result for result in result_all if ((result["K"]==16) and (result["num_kernels"]==30))]
# Out:
# []

# %%
result_all
# Out:
# [{'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 34),
#   'K': 16,
#   'num_kernels': 50},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 23),
#   'K': 16,
#   'num_kernels': 55},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 35),
#   'K': 16,
#   'num_kernels': 60},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 41),
#   'K': 16,
#   'num_kernels': 65},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 45),
#   'K': 16,
#   'num_kernels': 70},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 38),
#   'K': 16,
#   'num_kernels': 75},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 50),
#   'K': 16,
#   'num_kernels': 80},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 44),
#   'K': 16,
#   'num_kernels': 85},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 45),
#   'K': 16,
#   'num_kernels': 90},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 55),
#   'K': 16,
#   'num_kernels': 95},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 60),
#   'K': 16,
#   'num_kernels': 100},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 45),
#   'K': 16,
#   'num_kernels': 105},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 75),
#   'K': 16,
#   'num_kernels': 110},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 66),
#   'K': 16,
#   'num_kernels': 115},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 54),
#   'K': 16,
#   'num_kernels': 120},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 72),
#   'K': 16,
#   'num_kernels': 125},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 77),
#   'K': 16,
#   'num_kernels': 130},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 71),
#   'K': 16,
#   'num_kernels': 135},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 81),
#   'K': 16,
#   'num_kernels': 140},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 82),
#   'K': 16,
#   'num_kernels': 145},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 77),
#   'K': 16,
#   'num_kernels': 150},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 89),
#   'K': 16,
#   'num_kernels': 155},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 81),
#   'K': 16,
#   'num_kernels': 160},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 101),
#   'K': 16,
#   'num_kernels': 165},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 113),
#   'K': 16,
#   'num_kernels': 170},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 101),
#   'K': 16,
#   'num_kernels': 175},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 103),
#   'K': 16,
#   'num_kernels': 180},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 120),
#   'K': 16,
#   'num_kernels': 185},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 108),
#   'K': 16,
#   'num_kernels': 190},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 130),
#   'K': 16,
#   'num_kernels': 195},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 118),
#   'K': 16,
#   'num_kernels': 200},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 120),
#   'K': 16,
#   'num_kernels': 205},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 132),
#   'K': 16,
#   'num_kernels': 210},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 120),
#   'K': 16,
#   'num_kernels': 215},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 128),
#   'K': 16,
#   'num_kernels': 220},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 127),
#   'K': 16,
#   'num_kernels': 225},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 135),
#   'K': 16,
#   'num_kernels': 230},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 119),
#   'K': 16,
#   'num_kernels': 235},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 137),
#   'K': 16,
#   'num_kernels': 240},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 137),
#   'K': 16,
#   'num_kernels': 245},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 141),
#   'K': 16,
#   'num_kernels': 250},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 150),
#   'K': 16,
#   'num_kernels': 255},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 148),
#   'K': 16,
#   'num_kernels': 260},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 150),
#   'K': 16,
#   'num_kernels': 265},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 143),
#   'K': 16,
#   'num_kernels': 270},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 167),
#   'K': 16,
#   'num_kernels': 275},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 147),
#   'K': 16,
#   'num_kernels': 280},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 175),
#   'K': 16,
#   'num_kernels': 285},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 152),
#   'K': 16,
#   'num_kernels': 290},
#  {'estimator': SpectralClustering(assign_labels='cluster_qr', n_clusters=4,
#                      random_state=202304),
#   'X_shape': (136, 172),
#   'K': 16,
#   'num_kernels': 295}]
