# %% [markdown]
# # Compare results from different ROCKET methods
# 1. ROCKET
# 2. miniROCKET
# 3. multiROCKET

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sktime.classification.kernel_based import RocketClassifier

from datasets import BalancedDataset
from param import *

datalist = ParamDir().data_path_list

data_dir = datalist[2] # a wild-type mouse
dataset = BalancedDataset(data_dir, 1.0, False)

(X_train, y_train), (X_test, y_test) = dataset.load_all_data(10, .8)

# %% [markdown]
# ## Multivariate Rocket

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

rocket = RocketClassifier(
    rocket_transform="rocket",
    use_multivariate="yes"
    )
param_grid = {"num_kernels": [2**i for i in range(2, 12)]}
parameter_tuning_method = GridSearchCV(rocket, param_grid, cv=KFold(n_splits=5))
parameter_tuning_method.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=RocketClassifier(use_multivariate='yes'),
#              param_grid={'num_kernels': [4, 8, 16, 32, 64, 128, 256, 512, 1024,
#                                          2048]})

# %%
fig, ax = plt.subplots()
results = parameter_tuning_method.cv_results_
xx = [i['num_kernels'] for i in results['params']]
mean_score = results['mean_test_score']
std_score = results['std_test_score']
ax.plot(xx, mean_score)
ax.fill_between(xx, mean_score-std_score, mean_score+std_score, alpha=0.2)

# %%
[i['num_kernels'] for i in results['params']]
# Out:
# [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048]

# %%
y_pred = parameter_tuning_method.predict(X_test)
np.sum(y_test == y_pred)/len(y_test)
# Out:
# 0.25

# %% [markdown]
# ## Multivarate miniROCKET

# %%
rocket = RocketClassifier(
    rocket_transform="minirocket",
    use_multivariate="yes"
    )
param_grid = {"num_kernels": [2**i for i in range(2, 12)]}
parameter_tuning_method = GridSearchCV(rocket, param_grid, cv=KFold(n_splits=5))
parameter_tuning_method.fit(X_train, y_train)
rocket.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 25 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sktime/classification/base.py", line 191, in fit
#     self._fit(X, y)
#   File "/usr/local/lib/python3.8/site-packages/sktime/classification/_delegate.py", line 66, in _fit
#     estimator.fit(X=X, y=y)
#   File "/usr/local/lib/python3.8/site-packages/sktime/classification/base.py", line 191, in fit
#     self._fit(X, y)
#   File "/usr/local/lib/python3.8/site-packages/sktime/classification/compose/_pipeline.py", line 521, in _fit
#     Xt = self.transformers_.fit_transform(X=X, y=y)
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/base.py", line 575, in fit_transform
#     return self.fit(X, y).transform(X, y)
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/base.py", line 415, in fit
#     self._fit(X=X_inner, y=y_inner)
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/compose.py", line 325, in _fit
#     Xt = transformer.fit_transform(X=Xt, y=y)
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/base.py", line 575, in fit_transform
#     return self.fit(X, y).transform(X, y)
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/base.py", line 415, in fit
#     self._fit(X=X_inner, y=y_inner)
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/panel/rocket/_minirocket_multivariate.py", line 123, in _fit
#     self.parameters = _fit_multi(
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/panel/rocket/_minirocket_multi_numba.py", line 431, in _fit_multi
#     dilations, num_features_per_dilation = _fit_dilations(
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/panel/rocket/_minirocket_multi_numba.py", line 394, in _fit_dilations
#     multiplier = num_features_per_kernel / true_max_dilations_per_kernel
# ZeroDivisionError: division by zero
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan 0.28909091
#  0.26909091 0.26545455 0.28545455 0.30545455]
#   warnings.warn(
# RocketClassifier(rocket_transform='minirocket', use_multivariate='yes')

# %%
fig, ax = plt.subplots()
results = parameter_tuning_method.cv_results_
xx = [i['num_kernels'] for i in results['params']]
mean_score = results['mean_test_score']
std_score = results['std_test_score']
ax.plot(xx, mean_score)
ax.fill_between(xx, mean_score-std_score, mean_score+std_score, alpha=0.2)

# %%
y_pred = parameter_tuning_method.predict(X_test)
np.sum(y_test == y_pred)/len(y_test)
# Out:
# 0.375

# %% [markdown]
# ## Multivarate multiROCKET

# %%
rocket = RocketClassifier(
    rocket_transform="multirocket",
    use_multivariate="yes"
    )
param_grid = {"num_kernels": [2**i for i in range(2, 12)]}
parameter_tuning_method = GridSearchCV(rocket, param_grid, cv=KFold(n_splits=5))
parameter_tuning_method.fit(X_train, y_train)
rocket.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 25 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sktime/classification/base.py", line 191, in fit
#     self._fit(X, y)
#   File "/usr/local/lib/python3.8/site-packages/sktime/classification/_delegate.py", line 66, in _fit
#     estimator.fit(X=X, y=y)
#   File "/usr/local/lib/python3.8/site-packages/sktime/classification/base.py", line 191, in fit
#     self._fit(X, y)
#   File "/usr/local/lib/python3.8/site-packages/sktime/classification/compose/_pipeline.py", line 521, in _fit
#     Xt = self.transformers_.fit_transform(X=X, y=y)
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/base.py", line 575, in fit_transform
#     return self.fit(X, y).transform(X, y)
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/base.py", line 415, in fit
#     self._fit(X=X_inner, y=y_inner)
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/compose.py", line 325, in _fit
#     Xt = transformer.fit_transform(X=Xt, y=y)
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/base.py", line 575, in fit_transform
#     return self.fit(X, y).transform(X, y)
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/base.py", line 415, in fit
#     self._fit(X=X_inner, y=y_inner)
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/panel/rocket/_multirocket_multivariate.py", line 134, in _fit
#     self.parameter = self._get_parameter(X)
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/panel/rocket/_multirocket_multivariate.py", line 199, in _get_parameter
#     dilations, num_features_per_dilation = _fit_dilations(
#   File "/usr/local/lib/python3.8/site-packages/sktime/transformations/panel/rocket/_multirocket_multi_numba.py", line 384, in _fit_dilations
#     multiplier = num_features_per_kernel / true_max_dilations_per_kernel
# ZeroDivisionError: division by zero
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan 0.26727273
#  0.38363636 0.34363636 0.34545455 0.26909091]
#   warnings.warn(
# RocketClassifier(rocket_transform='multirocket', use_multivariate='yes')

# %%
fig, ax = plt.subplots()
results = parameter_tuning_method.cv_results_
xx = [i['num_kernels'] for i in results['params']]
mean_score = results['mean_test_score']
std_score = results['std_test_score']
ax.plot(xx, mean_score)
ax.fill_between(xx, mean_score-std_score, mean_score+std_score, alpha=0.2)

# %%
y_pred = parameter_tuning_method.predict(X_test)
np.sum(y_test == y_pred)/len(y_test)
# Out:
# 0.25
